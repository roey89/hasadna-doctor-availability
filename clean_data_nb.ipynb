# %%
# pip install geopy geopandas shapely

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import prepare_data

# %%
data = prepare_data.open_and_clean_all(
    "data/raw/clalit/parallel",
    "data/raw/maccabi/maccabi_full_data_with_appointments.json",
)

# %%
data.to_csv("data/clean/merged.csv", index=False)
data[data["kupah"] == "maccabi"].to_csv("data/clean/maccabi.csv", index=False)
data[data["kupah"] == "clalit"].to_csv("data/clean/clalit.csv", index=False)

# %%
data
# Out:
#                        timestamp      available_date    kupah profession  \
# 0     2026-07-30 16:51:12.000000 2026-08-02 00:00:00   clalit  אורתופדיה
# 1     2026-07-30 16:51:12.000000 2026-08-02 00:00:00   clalit  אורתופדיה
# 2     2026-07-30 16:51:12.000000 2026-08-03 00:00:00   clalit  אורתופדיה
# 3     2026-07-30 16:51:12.000000 2026-08-03 00:00:00   clalit  אורתופדיה
# 4     2026-07-30 16:51:12.000000 2026-08-03 00:00:00   clalit  אורתופדיה
# ...                          ...                 ...      ...        ...
# 13587 2026-07-31 11:16:39.116111 2026-09-30 08:24:00  maccabi  רפואת הפה
# 13588 2026-07-31 11:16:39.116111 2026-10-13 10:00:00  maccabi  רפואת הפה
# 13589 2026-07-31 11:16:39.116111 2026-10-19 17:00:00  maccabi  רפואת הפה
# 13590 2026-07-31 11:16:39.116111 2027-01-06 09:00:00  maccabi  רפואת הפה
# 13591 2026-07-31 11:16:39.116111                 NaT  maccabi  רפואת הפה
#
#                doctor_name                           address  days_diff  \
# 0            ד"ר לוין מארק                      שיאון, קצרין        3.0
# 1           ד"ר מחאמיד חסן                        מעלה עירון        3.0
# 2      ד"ר סמניסטי אלכסנדר                החשמונאים 1, טבריה        4.0
# 3         ד"ר אבראהים נדיר                               צפת        4.0
# 4         ד"ר קליימן מיכאל  מעלה חוני המעגל 12, חצור הגלילית        4.0
# ...                    ...                               ...        ...
# 13587       דר מור בר אילן          שפיגל זוסיה 3, פתח תקווה       61.0
# 13588       דר מור בר אילן                   הנדיב 3, הרצליה       74.0
# 13589      דר אנה פיקובסקי         שד רגר יצחק 53/2, באר שבע       80.0
# 13590         דר אסנת קורן                ביל"ו 51 ג', רעננה      159.0
# 13591    דר רינת שוימר נוי                   הלל 14, ירושלים        NaN
#
#                city
# 0             קצרין
# 1        מעלה עירון
# 2             טבריה
# 3               צפת
# 4      חצור הגלילית
# ...             ...
# 13587     פתח תקווה
# 13588        הרצליה
# 13589       באר שבע
# 13590         רעננה
# 13591       ירושלים
#
# [13592 rows x 8 columns]

# %%
data.drop(columns=["timestamp"]).drop_duplicates()
# Out:
#            available_date    kupah profession          doctor_name  \
# 0     2026-08-02 00:00:00   clalit  אורתופדיה        ד"ר לוין מארק
# 1     2026-08-02 00:00:00   clalit  אורתופדיה       ד"ר מחאמיד חסן
# 2     2026-08-03 00:00:00   clalit  אורתופדיה  ד"ר סמניסטי אלכסנדר
# 3     2026-08-03 00:00:00   clalit  אורתופדיה     ד"ר אבראהים נדיר
# 4     2026-08-03 00:00:00   clalit  אורתופדיה     ד"ר קליימן מיכאל
# ...                   ...      ...        ...                  ...
# 13587 2026-09-30 08:24:00  maccabi  רפואת הפה       דר מור בר אילן
# 13588 2026-10-13 10:00:00  maccabi  רפואת הפה       דר מור בר אילן
# 13589 2026-10-19 17:00:00  maccabi  רפואת הפה      דר אנה פיקובסקי
# 13590 2027-01-06 09:00:00  maccabi  רפואת הפה         דר אסנת קורן
# 13591                 NaT  maccabi  רפואת הפה    דר רינת שוימר נוי
#
#                                 address  days_diff          city
# 0                          שיאון, קצרין        3.0         קצרין
# 1                            מעלה עירון        3.0    מעלה עירון
# 2                    החשמונאים 1, טבריה        4.0         טבריה
# 3                                   צפת        4.0           צפת
# 4      מעלה חוני המעגל 12, חצור הגלילית        4.0  חצור הגלילית
# ...                                 ...        ...           ...
# 13587          שפיגל זוסיה 3, פתח תקווה       61.0     פתח תקווה
# 13588                   הנדיב 3, הרצליה       74.0        הרצליה
# 13589         שד רגר יצחק 53/2, באר שבע       80.0       באר שבע
# 13590                ביל"ו 51 ג', רעננה      159.0         רעננה
# 13591                   הלל 14, ירושלים        NaN       ירושלים
#
# [13592 rows x 7 columns]
