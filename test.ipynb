# %%
# %load_ext autoreload
# %autoreload 2

# %%
import prepare_data

# %%
data = prepare_data.open_and_clean_all("diaries.csv", "")
# Out:
#             timestamp profession     doctor_name available_date  \
# 0 2026-07-30 13:01:20  אורתופדיה    ד"ר הלר אייל     2026-08-11
# 1 2026-07-30 13:01:20  אורתופדיה  ד"ר צרפתי ירון     2026-08-14
#
#                          address
# 0  דרך משה דיין 147, תל אביב יפו
# 1    אליהו ברלין 13, תל אביב יפו

# %%
data["city"].value_counts()
# Out:
# city
# תל אביב יפו    844
# בני ברק        294
# חולון          278
# הרצליה         276
# בת ים          268
# כפר סבא        184
# רמת גן         154
# רעננה          114
# גבעתיים         48
# טירה            44
# אזור            24
# קרני שומרון     22
# כוכב יאיר       16
# עמנואל          16
# אלפי מנשה       14
# ראשון לציון     14
# גבעת שמואל      10
# רמת השרון       10
# קדומים           8
# פתח תקווה        6
# צור יצחק         4
# בית שמש          4
# Name: count, dtype: int64
