# %%
import prepare_data

# %%
data = prepare_data.open_and_clean_df("diaries.csv")

# %%
data.head(5)
# Out:
#             scraped_at group_name  spec_name         doctor_name profession  \
# 0  2026-07-30T13:01:20  אורתופדיה  אורתופדיה        ד"ר הלר אייל  אורתופדיה
# 1  2026-07-30T13:01:20  אורתופדיה  אורתופדיה      ד"ר צרפתי ירון  אורתופדיה
# 2  2026-07-30T13:01:20  אורתופדיה  אורתופדיה       ד"ר אשכול זאב  אורתופדיה
# 3  2026-07-30T13:01:20  אורתופדיה  אורתופדיה        ד"ר סודיה דן  אורתופדיה
# 4  2026-07-30T13:01:20  אורתופדיה  אורתופדיה  ד"ר לשינר ויאצ'סלב  אורתופדיה
#
#   next_available_date  days_until                                clinic_name  \
# 0          11.08.2026        12.0                        רמת ישראל - תל אביב
# 1          14.08.2026        15.0                         אזורי חן - תל אביב
# 2          16.08.2026        17.0  מגדל המאה - המרכז לרפואה יועצת - תל אביב
# 3          16.08.2026        17.0                        קרית שלום - תל אביב
# 4          17.08.2026        18.0                ד"ר לשינר ויאצסלב - תל אביב
#
#                      clinic_address
# ...
