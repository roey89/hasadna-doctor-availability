# %%
# pip install geopy geopandas shapely

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import prepare_data

# %%
data = prepare_data.open_and_clean_all(
    "data/raw/clalit/diaries.csv",
    "data/raw/maccabi/maccabi_full_data_with_appointments.json",
)

# %%
data.head(5)
# Out:
#             timestamp available_date   kupah profession         doctor_name  \
# 0 2026-07-30 13:01:20     2026-08-11  clalit  אורתופדיה        ד"ר הלר אייל
# 1 2026-07-30 13:01:20     2026-08-14  clalit  אורתופדיה      ד"ר צרפתי ירון
# 2 2026-07-30 13:01:20     2026-08-16  clalit  אורתופדיה       ד"ר אשכול זאב
# 3 2026-07-30 13:01:20     2026-08-16  clalit  אורתופדיה        ד"ר סודיה דן
# 4 2026-07-30 13:01:20     2026-08-17  clalit  אורתופדיה  ד"ר לשינר ויאצ'סלב
#
#                             address  days_diff         city
# 0     דרך משה דיין 147, תל אביב יפו       12.0  תל אביב יפו
# 1       אליהו ברלין 13, תל אביב יפו       15.0  תל אביב יפו
# 2       אבן גבירול 124, תל אביב יפו       17.0  תל אביב יפו
# 3  שדרות ישראל גורי 39, תל אביב יפו       17.0  תל אביב יפו
# 4    שדרות יד לבנים 35, תל אביב יפו       18.0  תל אביב יפו

# %%
data.to_csv("data/clean/maccabi.csv", index=False)
data[data["kupah"] == "maccabi"].to_csv("data/clean/maccabi.csv", index=False)
data[data["kupah"] == "clalit"].to_csv("data/clean/clalit.csv", index=False)

# %%
data
# Out:
#                       timestamp      available_date    kupah  \
# 0    2026-07-30 13:01:20.000000 2026-08-11 00:00:00   clalit
# 1    2026-07-30 13:01:20.000000 2026-08-14 00:00:00   clalit
# 2    2026-07-30 13:01:20.000000 2026-08-16 00:00:00   clalit
# 3    2026-07-30 13:01:20.000000 2026-08-16 00:00:00   clalit
# 4    2026-07-30 13:01:20.000000 2026-08-17 00:00:00   clalit
# ...                         ...                 ...      ...
# 3423 2026-07-31 00:42:36.208368 2026-10-04 16:00:00  maccabi
# 3424 2026-07-31 00:42:36.208368 2027-07-12 08:40:00  maccabi
# 3425 2026-07-31 00:42:36.208368 2026-10-26 10:45:00  maccabi
# 3426 2026-07-31 00:42:36.208368 2026-09-20 08:40:00  maccabi
# 3427 2026-07-31 00:42:36.208368 2026-10-19 17:00:00  maccabi
#
#                                              profession  \
# 0                                             אורתופדיה
# 1                                             אורתופדיה
# 2                                             אורתופדיה
# 3                                             אורתופדיה
# 4                                             אורתופדיה
# ...                                                 ...
# 3423  קרדיולוגיה - הפרעות קצב (אלקטרופיזיולוגיה וקוצ...
# 3424                                        ראומטולוגיה
# 3425                                        ראומטולוגיה
# 3426                             רפואה שיקומית/פיזיקלית
# 3427                                          רפואת הפה
#
#                 doctor_name                           address  days_diff  \
# 0              ד"ר הלר אייל     דרך משה דיין 147, תל אביב יפו       12.0
# 1            ד"ר צרפתי ירון       אליהו ברלין 13, תל אביב יפו       15.0
# 2             ד"ר אשכול זאב       אבן גבירול 124, תל אביב יפו       17.0
# 3              ד"ר סודיה דן  שדרות ישראל גורי 39, תל אביב יפו       17.0
# 4        ד"ר לשינר ויאצ'סלב    שדרות יד לבנים 35, תל אביב יפו       18.0
# ...                     ...                               ...        ...
# 3423        פרופ מרדכי חיים            בן צבי יצחק 2, באר שבע       65.0
# 3424  דר ורוניק סייג-בוכריס                  התקוה 4, באר שבע      346.0
# 3425    דר מירית עמית-וזינה           שד העצמאות 64, קריית גת       87.0
# 3426    דר סלימאן אלגרינאוי                  התקוה 4, באר שבע       51.0
# 3427        דר אנה פיקובסקי         שד רגר יצחק 53/2, באר שבע       80.0
#
#              city
# 0     תל אביב יפו
# 1     תל אביב יפו
# 2     תל אביב יפו
# 3     תל אביב יפו
# 4     תל אביב יפו
# ...           ...
# 3423      באר שבע
# 3424      באר שבע
# 3425     קריית גת
# 3426      באר שבע
# 3427      באר שבע
#
# [3428 rows x 8 columns]
