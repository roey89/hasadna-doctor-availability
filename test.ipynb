# %%
# pip install geopy geopandas shapely

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import prepare_data

# %%
data = prepare_data.open_and_clean_all(
    "data/raw/clalit/diaries.csv",
    "data/raw/maccabi/maccabi_full_data_with_appointments.json",
)

# %%
data.tail(5)
# Out:
#                        timestamp      available_date    kupah profession  \
# 13965 2026-07-31 10:24:55.782577 2026-09-30 08:24:00  maccabi  רפואת הפה
# 13966 2026-07-31 10:24:55.782577 2026-10-13 10:00:00  maccabi  רפואת הפה
# 13967 2026-07-31 10:24:55.782577 2026-10-19 17:00:00  maccabi  רפואת הפה
# 13968 2026-07-31 10:24:55.782577 2027-01-06 09:00:00  maccabi  רפואת הפה
# 13969 2026-07-31 10:24:55.782577                 NaT  maccabi  רפואת הפה
#
#              doctor_name                    address  days_diff       city
# 13965     דר מור בר אילן   שפיגל זוסיה 3, פתח תקווה       61.0  פתח תקווה
# 13966     דר מור בר אילן            הנדיב 3, הרצליה       74.0     הרצליה
# 13967    דר אנה פיקובסקי  שד רגר יצחק 53/2, באר שבע       80.0    באר שבע
# 13968       דר אסנת קורן         ביל"ו 51 ג', רעננה      159.0      רעננה
# 13969  דר רינת שוימר נוי            הלל 14, ירושלים        NaN    ירושלים

# %%
data.to_csv("data/clean/merged.csv", index=False)
data[data["kupah"] == "maccabi"].to_csv("data/clean/maccabi.csv", index=False)
data[data["kupah"] == "clalit"].to_csv("data/clean/clalit.csv", index=False)

# %%
data
# Out:
#                        timestamp      available_date    kupah profession  \
# 0     2026-07-30 13:01:20.000000 2026-08-11 00:00:00   clalit  אורתופדיה
# 1     2026-07-30 13:01:20.000000 2026-08-14 00:00:00   clalit  אורתופדיה
# 2     2026-07-30 13:01:20.000000 2026-08-16 00:00:00   clalit  אורתופדיה
# 3     2026-07-30 13:01:20.000000 2026-08-16 00:00:00   clalit  אורתופדיה
# 4     2026-07-30 13:01:20.000000 2026-08-17 00:00:00   clalit  אורתופדיה
# ...                          ...                 ...      ...        ...
# 13965 2026-07-31 10:24:55.782577 2026-09-30 08:24:00  maccabi  רפואת הפה
# 13966 2026-07-31 10:24:55.782577 2026-10-13 10:00:00  maccabi  רפואת הפה
# 13967 2026-07-31 10:24:55.782577 2026-10-19 17:00:00  maccabi  רפואת הפה
# 13968 2026-07-31 10:24:55.782577 2027-01-06 09:00:00  maccabi  רפואת הפה
# 13969 2026-07-31 10:24:55.782577                 NaT  maccabi  רפואת הפה
#
#               doctor_name                           address  days_diff  \
# 0            ד"ר הלר אייל     דרך משה דיין 147, תל אביב יפו       12.0
# 1          ד"ר צרפתי ירון       אליהו ברלין 13, תל אביב יפו       15.0
# 2           ד"ר אשכול זאב       אבן גבירול 124, תל אביב יפו       17.0
# 3            ד"ר סודיה דן  שדרות ישראל גורי 39, תל אביב יפו       17.0
# 4      ד"ר לשינר ויאצ'סלב    שדרות יד לבנים 35, תל אביב יפו       18.0
# ...                   ...                               ...        ...
# 13965      דר מור בר אילן          שפיגל זוסיה 3, פתח תקווה       61.0
# 13966      דר מור בר אילן                   הנדיב 3, הרצליה       74.0
# 13967     דר אנה פיקובסקי         שד רגר יצחק 53/2, באר שבע       80.0
# 13968        דר אסנת קורן                ביל"ו 51 ג', רעננה      159.0
# 13969   דר רינת שוימר נוי                   הלל 14, ירושלים        NaN
#
#               city
# 0      תל אביב יפו
# 1      תל אביב יפו
# 2      תל אביב יפו
# 3      תל אביב יפו
# 4      תל אביב יפו
# ...            ...
# 13965    פתח תקווה
# 13966       הרצליה
# 13967      באר שבע
# 13968        רעננה
# 13969      ירושלים
#
# [13970 rows x 8 columns]
